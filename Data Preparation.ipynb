# %% [markdown]
# # Dataset Preparation
#
# ## 1. Introduction to the dataset
#
# The dataset presented here contains information on all conflicts that happened in Africa from 1997 to 2020.
#
# Source :  https://www.acleddata.com
# The Armed Conflict Location & Event Data Project (ACLED) is a disaggregated data collection, analysis, and crisis mapping project. ACLED collects the dates, actors, locations, fatalities, and types of all reported political violence and protest events across Africa, East Asia, South Asia, Southeast Asia, the Middle East, Central Asia and the Caucasus, Latin America and the Caribbean, and Southeastern and Eastern Europe and the Balkans. The ACLED team conducts analysis to describe, explore, and test conflict scenarios, and makes both data and analysis open for free use by the public.
# ACLED is a registered non-profit organization with 501(c)(3) status in the United States.
#
# To better understand the data columns this pdf file is provided by ACLED https://www.acleddata.com/wp-content/uploads/2017/12/ACLED-Data-Columns_Quick-ReferenceFINAL.pdf.
# You will also find this file with the notebook path.

# %% [markdown]
# ## 2. Dataset conversion
#
# The raw dataset material is provided in .xlsx format. Our aim is to first convert the dataset to a .cvs format for better data manipulation with pandas and other frameworks or libraries.

# %%
import pandas as pd
read_file = pd.read_excel(r'africa.xlsx')
read_file.to_csv(r'/home/psn/Hochschule/Project/africa.csv')

# %% [markdown]
# ## 3. Dataset reduction
# ### Removing unwanted rows
#
# The goal of this step is to remove unwanted data. As mentioned, the dataset contrains records from 1970 to 2020. We would like to have data only from 2010-12-17 ( The start of the arab spring, the date of the self-immolation of Mohamed Bouazizi ) to 2020.

# %%
dataframe = pd.read_csv('africa.csv')
dframe = dataframe[dataframe.EVENT_DATE > '2010-12-17']
dframe.head(3)
# Out:
#       Unnamed: 0  ISO EVENT_ID_CNTY  EVENT_ID_NO_CNTY  EVENT_DATE  YEAR  \
# 2483        2483   12       ALG2538              2538  2010-12-20  2010
# 2484        2484   12       ALG2539              2539  2010-12-25  2010
# 2485        2485   12       ALG2540              2540  2010-12-26  2010
#
#       TIME_PRECISION EVENT_TYPE         SUB_EVENT_TYPE  \
# 2483               1    Battles            Armed clash
# 2484               1      Riots  Violent demonstration
# 2485               1    Battles            Armed clash
#
#                                      ACTOR1  ... ADMIN3     LOCATION LATITUDE  \
# 2483     Military Forces of Algeria (1999-)  ...    NaN  Ait Dahmane   36.611
# 2484       Police Forces of Algeria (1999-)  ...    NaN      Algiers   36.752
# 2485  AQIM: Al Qaeda in the Islamic Maghreb  ...    NaN        Jijel   36.800
#
#      LONGITUDE  GEO_PRECISION             SOURCE   SOURCE_SCALE  \
# 2483     3.577              1        TSA Algerie       National
# 2484     3.042              1  Liberte (Algeria)       National
# 2485     5.767              2             Xinhua  International
#
#                                                   NOTES FATALITIES   TIMESTAMP
# 2483  A militant was captured by security forces on ...          0  1563903165
# 2484  Riots broke out in districts covered by the pr...          0  1579554013
# 2485  Two AQLMI militants are killed and five wounde...          2  1572403789
#
# [3 rows x 30 columns]

# %% [markdown]
# ### Removing unwanted columns
#
# Some columns which will not be of importance to the purpose of using this dataset, judged as irrelevant, will be dropped. The columns to be dropped are:
# * EVENT_ID_CNTY
# * EVENT_ID_NO_CNTY
# * YEAR
# * TIME_PRECISION
# * INTER1
# * INTER2
# * ADMIN3
# * LATITUDE
# * LONGITUDE
# * GEO_PRECISION
# * SOURCE_SCALE
# * TIMESTAMP

# %%
del dframe['EVENT_ID_CNTY']
del dframe['EVENT_ID_NO_CNTY']
del dframe['YEAR']
del dframe['TIME_PRECISION']
del dframe['INTER1']
del dframe['INTER2']
del dframe['ADMIN3']
del dframe['LATITUDE']
del dframe['LONGITUDE']
del dframe['GEO_PRECISION']
del dframe['SOURCE_SCALE']
del dframe['TIMESTAMP']
dframe.head(5)
# Out:
#       Unnamed: 0  ISO  EVENT_DATE EVENT_TYPE         SUB_EVENT_TYPE  \
# 2483        2483   12  2010-12-20    Battles            Armed clash
# 2484        2484   12  2010-12-25      Riots  Violent demonstration
# 2485        2485   12  2010-12-26    Battles            Armed clash
# 2486        2486   12  2010-12-27      Riots  Violent demonstration
# 2487        2487   12  2010-12-27      Riots  Violent demonstration
#
#                                      ACTOR1 ASSOC_ACTOR_1  \
# 2483     Military Forces of Algeria (1999-)           NaN
# 2484       Police Forces of Algeria (1999-)           NaN
# 2485  AQIM: Al Qaeda in the Islamic Maghreb           NaN
# 2486                      Rioters (Algeria)           NaN
# 2487       Police Forces of Algeria (1999-)           NaN
#
#                                   ACTOR2 ASSOC_ACTOR_2  INTERACTION  \
# 2483  Unidentified Armed Group (Algeria)           NaN           13
# 2484                   Rioters (Algeria)           NaN           15
# 2485  Military Forces of Algeria (1999-)           NaN           12
# 2486                                 NaN           NaN           50
# 2487                   Rioters (Algeria)           NaN           15
#
#                REGION  COUNTRY     ADMIN1        ADMIN2      LOCATION  \
# 2483  Northern Africa  Algeria  Boumerdes         Ammal   Ait Dahmane
# 2484  Northern Africa  Algeria      Alger  Sidi M'Hamed       Algiers
# 2485  Northern Africa  Algeria      Jijel         Jijel         Jijel
# 2486  Northern Africa  Algeria      Alger        Baraki        Baraki
# 2487  Northern Africa  Algeria      Alger  Sidi M'Hamed  Sidi M'Hamed
#
#                              SOURCE  \
# 2483                    TSA Algerie
# 2484              Liberte (Algeria)
# 2485                         Xinhua
# 2486              Liberte (Algeria)
# 2487  Liberte (Algeria); Al Jazeera
#
#                                                   NOTES  FATALITIES
# 2483  A militant was captured by security forces on ...           0
# 2484  Riots broke out in districts covered by the pr...           0
# 2485  Two AQLMI militants are killed and five wounde...           2
# 2486  Clashes have taken place in the city of Palmie...           0
# 2487  Clashes have taken place in the city of Palmie...           0
